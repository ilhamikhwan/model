# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml 
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %% [markdown]
# ### Load Custom Model

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
# !cd yolov5 && python train.py --img 640 --batch 20 --epoch 40 --data dataset.yml --weights yolov5m.pt --workers 2

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='last.pt')
# Out:
# Using cache found in C:\Users\IKHWAN/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-11-21 Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# Model summary: 322 layers, 86173414 parameters, 0 gradients, 203.8 GFLOPs
# Adding AutoShape...

# %%
img = 'data//val//124.jpg' 
results = model(img)
results.print()
# Out:
# image 1/1: 3473x4623 1 robot
# Speed: 219.5ms pre-process, 159.2ms inference, 283.7ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture('E://jupyternotebook//robot2.mp4')
while cap.isOpened():
    ret, frame = cap.read()
    
    frame = cv2.resize(frame, (1550,900), fx=0, fy=0, interpolation=cv2.INTER_AREA)
    results = model(frame)
    fps = cap.get(cv2.CAP_PROP_FPS)
    print(fps)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0
# 30.0

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/exp2/weights/last.pt --img 720 --conf 0.35 --source ../modelforobot/robot2.mp4
# Out:
# detect: weights=['yolov5/runs/train/exp2/weights/last.pt'], source=../modelforobot/robot2.mp4, data=yolov5\data\coco128.yaml, imgsz=[720, 720], conf_thres=0.35, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-238-gd5d514e Python-3.9.18 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# WARNING  --img-size [720, 720] must be multiple of max stride 32, updating to [736, 736]
# Traceback (most recent call last):
#   File "E:\jupyternotebook\modelforobot\yolov5\detect.py", line 285, in <module>
#     main(opt)
# ...
